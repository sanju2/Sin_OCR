# %%
# !pip install googledrivedownloader

from google_drive_downloader import GoogleDriveDownloader as gdd

file = gdd.download_file_from_google_drive(file_id='14dsQUnpUkKTXjSwc0nwQXMwjfeR3KA_1',
                                    dest_path='./iskolapotha.npz')
